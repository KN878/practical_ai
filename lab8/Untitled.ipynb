# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_color = cv2.imread('barrel.jpg', cv2.IMREAD_COLOR)
plt.figure(figsize=(75, 10))
# this is how you can fix colors for _presentation_
color_fixed = cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)
plt.imshow(color_fixed)
plt.show()

# %%
width = color_fixed.shape[0]
height = color_fixed.shape[1]

# %%
new_img = np.ndarray(shape = color_fixed.shape[:3], dtype=float)
centerX = width/2
centerY = height/2
k = pow(10, -7)

# %%
for x in range(0, width):
    for y in range(0, height):
        dx = centerX - x
        dy = centerY - y
        rd = np.sqrt(dx**2 + dy**2)
        r_new = rd * (1 + k*(rd**2))
        s = r_new/rd
        dxn = dx*s
        dyn = dy*s
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-1761d32664ff> in <module>
#       8         dxn = int(dx*s)
#       9         dyn = int(dy*s)
# ---> 10         new_img[x][y] = color_fixed[int(abs(centerX - dxn))][int(abs(centerY-dyn))]
#
# IndexError: index 1632 is out of bounds for axis 0 with size 1632

# %%
plt.figure(figsize=(75, 10))
# this is how you can fix colors for _presentation_
color_fixed = cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)
plt.imshow(new_img)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
